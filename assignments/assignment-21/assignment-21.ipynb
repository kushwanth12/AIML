# %% [markdown]
# # Assignment 20-06-20

# %% [markdown]
# # CSE-221710304037-N.kushwanth

# %% [markdown]
# Read the dataset from the below path:
# <a href="https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv">Dataset</a>
#
# <br>Check the data types and summary statistics of the dataset
# <br>Select random columns as Series and random columns as dataframe
# <br>Convert the data type of integer cols to float and float cols to integer
# <br>Visualize the missing values through heatmap
# <br>Dropt the duplicate values if found any
# <br>Get the row which has highest population
# <br>Calculate the mean of the population total grouped by States and sort the population total in ascending order and plot a <br>horizontal bar chart for that.
# <br>Create a dataframe of five cities which have lowest population
# <br>Create a dataframe of  five cities which have highest  population
# <br>Concatenate the top five and bottom five cities based on the population

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('cities.csv')
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
df.shape
# Out:
# (493, 22)

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
df.dtypes
# Out:
# name_of_city                       object
# state_code                          int64
# state_name                         object
# dist_code                           int64
# population_total                    int64
# population_male                     int64
# population_female                   int64
# 0-6_population_total                int64
# 0-6_population_male                 int64
# 0-6_population_female               int64
# literates_total                     int64
# literates_male                      int64
# literates_female                    int64
# sex_ratio                           int64
# child_sex_ratio                     int64
# effective_literacy_rate_total     float64
# effective_literacy_rate_male      float64
# effective_literacy_rate_female    float64
# location                           object
# total_graduates                     int64
# male_graduates                      int64
# female_graduates                    int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null int64
# state_name                        493 non-null object
# dist_code                         493 non-null int64
# population_total                  493 non-null int64
# population_male                   493 non-null int64
# population_female                 493 non-null int64
# 0-6_population_total              493 non-null int64
# 0-6_population_male               493 non-null int64
# 0-6_population_female             493 non-null int64
# literates_total                   493 non-null int64
# literates_male                    493 non-null int64
# literates_female                  493 non-null int64
# sex_ratio                         493 non-null int64
# child_sex_ratio                   493 non-null int64
# effective_literacy_rate_total     493 non-null float64
# ...

# %%
df.isna().sum()
# Out:
# name_of_city                      0
# state_code                        0
# state_name                        0
# dist_code                         0
# population_total                  0
# population_male                   0
# population_female                 0
# 0-6_population_total              0
# 0-6_population_male               0
# 0-6_population_female             0
# literates_total                   0
# literates_male                    0
# literates_female                  0
# sex_ratio                         0
# child_sex_ratio                   0
# effective_literacy_rate_total     0
# effective_literacy_rate_male      0
# effective_literacy_rate_female    0
# location                          0
# total_graduates                   0
# male_graduates                    0
# female_graduates                  0
# dtype: int64

# %%
df.describe()
# Out:
#        state_code   dist_code  population_total  population_male  \
# count  493.000000  493.000000      4.930000e+02     4.930000e+02
# mean    18.643002   16.782961      4.481124e+05     2.343468e+05
# std      9.297168   15.566131      1.033228e+06     5.487786e+05
# min      1.000000    1.000000      1.000360e+05     5.020100e+04
# 25%      9.000000    7.000000      1.261420e+05     6.638400e+04
# 50%     19.000000   13.000000      1.841330e+05     9.665500e+04
# 75%     27.000000   21.000000      3.490330e+05     1.750550e+05
# max     35.000000   99.000000      1.247845e+07     6.736815e+06
#
#        population_female  0-6_population_total  0-6_population_male  \
# count       4.930000e+02          4.930000e+02           493.000000
# mean        2.137656e+05          4.709285e+04         24849.527383
# std         4.848622e+05          1.050279e+05         55535.310272
# min         4.512600e+04          6.547000e+03          3406.000000
# ...

# %%
df.describe(include='O')
# Out:
#        name_of_city     state_name               location
# count           493            493                    493
# unique          492             29                    490
# top     Aurangabad   UTTAR PRADESH  18.9894007,73.1175162
# freq              2             63                      2

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of       name_of_city  state_code      state_name  dist_code  population_total  \
# 0          Abohar            3          PUNJAB          9            145238
# 1        Achalpur           27     MAHARASHTRA          7            112293
# 2        Adilabad           28  ANDHRA PRADESH          1            117388
# 3       Adityapur           20       JHARKHAND         24            173988
# 4           Adoni           28  ANDHRA PRADESH         21            166537
# ..             ...         ...             ...        ...               ...
# 488  Vizianagaram           28  ANDHRA PRADESH         12            227533
# 489      Warangal           28  ANDHRA PRADESH          9            620116
# 490        Wardha           27     MAHARASHTRA          8            105543
# 491   Yamunanagar            6         HARYANA          3            216628
# 492      Yavatmal           27     MAHARASHTRA         14            116714
#
# ...

# %%
import random

# %%
ser=pd.Series(df[random.choice(list(df.columns))])
ser
# Out:
# 0      848
# 1      909
# 2      947
# 3      910
# 4      968
#       ...
# 488    952
# 489    948
# 490    898
# 491    824
# 492    880
# Name: child_sex_ratio, Length: 493, dtype: int64

# %%
random_df=pd.DataFrame()
for i in range(5):
    ran=random.choice(list(df.columns))
    random_df[ran]=df[ran]
random_df
# Out:
#      state_code  child_sex_ratio  male_graduates  population_female  \
# 0             3              848            8612              68398
# 1            27              909            5269              54037
# 2            28              947            6797              58156
# 3            20              910           12189              82493
# 4            28              968            7871              83794
# ..          ...              ...             ...                ...
# 488          28              952           19173             115937
# 489          28              948           69507             309716
# 490          27              898           10645              52302
# 491           6              824           14349             101224
# 492          27              880            7397              57997
#
#      effective_literacy_rate_male
# 0                           85.49
# 1                           94.77
# 2                           88.18
# ...

# %%
float_col=df.select_dtypes(include="float64").columns
float_col
# Out:
# Index(['effective_literacy_rate_total', 'effective_literacy_rate_male',
#        'effective_literacy_rate_female'],
#       dtype='object')

# %%
int_col=df.select_dtypes(include="int64").columns
int_col
# Out:
# Index(['state_code', 'dist_code', 'population_total', 'population_male',
#        'population_female', '0-6_population_total', '0-6_population_male',
#        '0-6_population_female', 'literates_total', 'literates_male',
#        'literates_female', 'sex_ratio', 'child_sex_ratio', 'total_graduates',
#        'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
df[int_col]=df[int_col].astype(float)

# %%
df[int_col].dtypes
# Out:
# state_code               float64
# dist_code                float64
# population_total         float64
# population_male          float64
# population_female        float64
# 0-6_population_total     float64
# 0-6_population_male      float64
# 0-6_population_female    float64
# literates_total          float64
# literates_male           float64
# literates_female         float64
# sex_ratio                float64
# child_sex_ratio          float64
# total_graduates          float64
# male_graduates           float64
# female_graduates         float64
# dtype: object

# %%
df[float_col]=df[float_col].astype(int)

# %%
df[float_col].dtypes
# Out:
# effective_literacy_rate_total     int32
# effective_literacy_rate_male      int32
# effective_literacy_rate_female    int32
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 22 columns):
# name_of_city                      493 non-null object
# state_code                        493 non-null float64
# state_name                        493 non-null object
# dist_code                         493 non-null float64
# population_total                  493 non-null float64
# population_male                   493 non-null float64
# population_female                 493 non-null float64
# 0-6_population_total              493 non-null float64
# 0-6_population_male               493 non-null float64
# 0-6_population_female             493 non-null float64
# literates_total                   493 non-null float64
# literates_male                    493 non-null float64
# literates_female                  493 non-null float64
# sex_ratio                         493 non-null float64
# child_sex_ratio                   493 non-null float64
# ...

# %%
sns.heatmap(df.isna(),cmap="YlGnBu")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df[df.population_total==max(list(df.population_total))]
# Out:
#         name_of_city  state_code   state_name  dist_code  population_total  \
# 185  Greater Mumbai         27.0  MAHARASHTRA       99.0        12478447.0
#
#      population_male  population_female  0-6_population_total  \
# 185        6736815.0          5741632.0             1139146.0
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 185             599007.0               540139.0  ...         4509812.0
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 185      852.0            902.0                             90
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 185                            93                              86
#
#             location  total_graduates male_graduates  female_graduates
# 185  19.0760,72.8777        1802371.0       964964.0          837407.0
#
# [1 rows x 22 columns]

# %%
df[df.population_total==df.population_total.max()]
# Out:
#         name_of_city  state_code   state_name  dist_code  population_total  \
# 185  Greater Mumbai         27.0  MAHARASHTRA       99.0        12478447.0
#
#      population_male  population_female  0-6_population_total  \
# 185        6736815.0          5741632.0             1139146.0
#
#      0-6_population_male  0-6_population_female  ...  literates_female  \
# 185             599007.0               540139.0  ...         4509812.0
#
#      sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 185      852.0            902.0                             90
#
#      effective_literacy_rate_male  effective_literacy_rate_female  \
# 185                            93                              86
#
#             location  total_graduates male_graduates  female_graduates
# 185  19.0760,72.8777        1802371.0       964964.0          837407.0
#
# [1 rows x 22 columns]

# %%
df.groupby('state_name').mean().sort_values('population_total')
# Out:
#                            state_code  dist_code  population_total  \
# state_name
# ANDAMAN & NICOBAR ISLANDS        35.0   3.000000     100608.000000
# NAGALAND                         13.0   5.000000     123777.000000
# MEGHALAYA                        17.0   6.000000     143007.000000
# HIMACHAL PRADESH                  2.0  11.000000     169758.000000
# UTTARAKHAND                       5.0  11.000000     223399.500000
# BIHAR                            10.0  20.038462     258250.615385
# MANIPUR                          14.0  99.000000     264986.000000
# PUDUCHERRY                       34.0   2.000000     270900.500000
# MIZORAM                          15.0   3.000000     291822.000000
# WEST BENGAL                      19.0  12.491803     296123.098361
# HARYANA                           6.0   9.550000     297611.150000
# ORISSA                           21.0  10.300000     300323.400000
# MADHYA PRADESH                   23.0  22.406250     344471.593750
# ...

# %%
df.population_total.min()
# Out:
# 100036.0

# %%
bottom_five=df.sort_values('population_total').head()
bottom_five
# Out:
#     name_of_city  state_code                 state_name  dist_code  \
# 332       Nagda         23.0             MADHYA PRADESH       18.0
# 53     Banswara          8.0                  RAJASTHAN       27.0
# 211  Hinganghat         27.0                MAHARASHTRA        8.0
# 136       Datia         23.0             MADHYA PRADESH        5.0
# 376  Port Blair         35.0  ANDAMAN & NICOBAR ISLANDS        3.0
#
#      population_total  population_male  population_female  \
# 332          100036.0          51410.0            48626.0
# 53           100128.0          51240.0            48888.0
# 211          100416.0          51881.0            48535.0
# 136          100466.0          52931.0            47535.0
# 376          100608.0          53247.0            47361.0
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 332               11053.0               5840.0                 5213.0  ...
# ...

# %%
df.population_total.max()
# Out:
# 12478447.0

# %%
top_five=df.sort_values('population_total',ascending=False).head()
top_five
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai         27.0     MAHARASHTRA       99.0
# 141              Delhi          7.0    NCT OF DELHI       99.0
# 72            Bengaluru        29.0       KARNATAKA       18.0
# 184  Greater Hyderabad         28.0  ANDHRA PRADESH       99.0
# 7            Ahmadabad         24.0         GUJARAT        7.0
#
#      population_total  population_male  population_female  \
# 185        12478447.0        6736815.0          5741632.0
# 141        11007835.0        5871362.0          5136473.0
# 72          8425970.0        4401299.0          4024671.0
# 184         6809970.0        3500802.0          3309168.0
# 7           5570585.0        2935869.0          2634716.0
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 185             1139146.0             599007.0               540139.0  ...
# 141             1209275.0             647938.0               561337.0  ...
# ...

# %%
pd.concat([top_five,bottom_five],axis=0)
# Out:
#            name_of_city  state_code                 state_name  dist_code  \
# 185     Greater Mumbai         27.0                MAHARASHTRA       99.0
# 141              Delhi          7.0               NCT OF DELHI       99.0
# 72            Bengaluru        29.0                  KARNATAKA       18.0
# 184  Greater Hyderabad         28.0             ANDHRA PRADESH       99.0
# 7            Ahmadabad         24.0                    GUJARAT        7.0
# 332              Nagda         23.0             MADHYA PRADESH       18.0
# 53            Banswara          8.0                  RAJASTHAN       27.0
# 211         Hinganghat         27.0                MAHARASHTRA        8.0
# 136              Datia         23.0             MADHYA PRADESH        5.0
# 376         Port Blair         35.0  ANDAMAN & NICOBAR ISLANDS        3.0
#
#      population_total  population_male  population_female  \
# 185        12478447.0        6736815.0          5741632.0
# ...
