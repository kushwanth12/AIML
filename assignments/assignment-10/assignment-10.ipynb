# %% [markdown]
# # Assignment 06-06-20

# %% [markdown]
# # CSE-221710304037-N.kushwanth

# %% [markdown]
# Use the following link for solving the given assignment Questions
#
# <br>https://raw.githubusercontent.com/kotagiri-preeti/Summer-Internship-AI-and-ML/master/german_credit_data.csv
#
# <br>If you find Unnamed column in the data remove that by filtering
# <br>Display the top seven rows and last Three rows
# <br>Check the total number of entries you have
# <br>Check the No of features,Print features Names(Column Names)
# <br>Print the row indices of the dataframe
# <br>Check the dtype of each and every columns
# <br>Description for Numerical Column min,max,count,25%,50%,75%,std
# <br>Description for the categorical Columns count,top,freq
# <br>Missing value count column wise
# <br>Check the output for the info function
# <br>Access particular rows and columns using iloc,loc
# <br>How many unique values are there in a particular column

# %%
import numpy as np
import pandas as pd

# %%
data_frame=pd.read_csv("test.csv")
data_frame
# Out:
#      Unnamed: 0  Age     Sex  Job Housing Saving accounts Checking account  \
# 0             0   67    male    2     own             NaN           little
# 1             1   22  female    2     own          little         moderate
# 2             2   49    male    1     own          little              NaN
# 3             3   45    male    2    free          little           little
# 4             4   53    male    2    free          little           little
# ..          ...  ...     ...  ...     ...             ...              ...
# 995         995   31  female    1     own          little              NaN
# 996         996   40    male    3     own          little           little
# 997         997   38    male    2     own          little              NaN
# 998         998   23    male    2    free          little           little
# 999         999   27    male    2     own        moderate         moderate
#
#      Credit amount  Duration              Purpose
# ...

# %%
data_frame.drop(data_frame.columns[[0]],axis=1,inplace=True)
data_frame
# Out:
#      Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0     67    male    2     own             NaN           little           1169
# 1     22  female    2     own          little         moderate           5951
# 2     49    male    1     own          little              NaN           2096
# 3     45    male    2    free          little           little           7882
# 4     53    male    2    free          little           little           4870
# ..   ...     ...  ...     ...             ...              ...            ...
# 995   31  female    1     own          little              NaN           1736
# 996   40    male    3     own          little           little           3857
# 997   38    male    2     own          little              NaN            804
# 998   23    male    2    free          little           little           1845
# 999   27    male    2     own        moderate         moderate           4576
#
# ...

# %%
print("these are the top 7 rows:\n\n")
data_frame.head(7)
# Out:
# these are the top 7 rows:
#    Age     Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 0   67    male    2     own             NaN           little           1169
# 1   22  female    2     own          little         moderate           5951
# 2   49    male    1     own          little              NaN           2096
# 3   45    male    2    free          little           little           7882
# 4   53    male    2    free          little           little           4870
# 5   35    male    1    free             NaN              NaN           9055
# 6   53    male    2     own      quite rich              NaN           2835
#
#    Duration              Purpose
# 0         6             radio/TV
# 1        48             radio/TV
# 2        12            education
# 3        42  furniture/equipment
# 4        24                  car
# 5        36            education
# 6        24  furniture/equipment

# %%
print("these are the last 3 rows:\n\n")
data_frame.tail(3)
# Out:
# these are the last 3 rows:
#      Age   Sex  Job Housing Saving accounts Checking account  Credit amount  \
# 997   38  male    2     own          little              NaN            804
# 998   23  male    2    free          little           little           1845
# 999   27  male    2     own        moderate         moderate           4576
#
#      Duration   Purpose
# 997        12  radio/TV
# 998        45  radio/TV
# 999        45       car

# %%
print("shape of data_frame is:",data_frame.shape,"\n No. of entries in data_frame is:",data_frame.shape[0])
# Out:
# shape of data_frame is: (1000, 9)
#  No. of entries in data_frame is: 1000

# %%
print("These are the columns in data_frame:")
print(list(data_frame.columns))
print("No. of columns:",len(list(data_frame)))
# Out:
# These are the columns in data_frame:
# ['Age', 'Sex', 'Job', 'Housing', 'Saving accounts', 'Checking account', 'Credit amount', 'Duration', 'Purpose']
# No. of columns: 9

# %%
pd.set_option('display.max_rows',10000)

# %%
print("row indices of data_frame:")
for i in data_frame.index:
    print(i,end=",")
# Out:
# row indices of data_frame:
# ...

# %%
for i in data_frame.columns:
    print(i," column is \"",data_frame[i].dtypes,"\" type")
# Out:
# Age  column is " int64 " type
# Sex  column is " object " type
# Job  column is " int64 " type
# Housing  column is " object " type
# Saving accounts  column is " object " type
# Checking account  column is " object " type
# Credit amount  column is " int64 " type
# Duration  column is " int64 " type
# Purpose  column is " object " type

# %%
data_frame.dtypes
# Out:
# Age                  int64
# Sex                 object
# Job                  int64
# Housing             object
# Saving accounts     object
# Checking account    object
# Credit amount        int64
# Duration             int64
# Purpose             object
# dtype: object

# %%
print("Description for Numerical Column min,max,count,25%,50%,75%,std:")
data_frame.describe()
# Out:
# Description for Numerical Column min,max,count,25%,50%,75%,std:
#                Age          Job  Credit amount     Duration
# count  1000.000000  1000.000000    1000.000000  1000.000000
# mean     35.546000     1.904000    3271.258000    20.903000
# std      11.375469     0.653614    2822.736876    12.058814
# min      19.000000     0.000000     250.000000     4.000000
# 25%      27.000000     2.000000    1365.500000    12.000000
# 50%      33.000000     2.000000    2319.500000    18.000000
# 75%      42.000000     2.000000    3972.250000    24.000000
# max      75.000000     3.000000   18424.000000    72.000000

# %%
print("Description for the categorical Columns count,top,freq:")
data_frame.describe(include=['O'])
# Out:
# Description for the categorical Columns count,top,freq:
#          Sex Housing Saving accounts Checking account Purpose
# count   1000    1000             817              606    1000
# unique     2       3               4                3       8
# top     male     own          little           little     car
# freq     690     713             603              274     337

# %%
print("Missing value count column wise:")
data_frame.isna().sum()
# Out:
# Missing value count column wise:
# Age                   0
# Sex                   0
# Job                   0
# Housing               0
# Saving accounts     183
# Checking account    394
# Credit amount         0
# Duration              0
# Purpose               0
# dtype: int64

# %%
print("This is the INFO:")
data_frame.info()
# Out:
# This is the INFO:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
# Age                 1000 non-null int64
# Sex                 1000 non-null object
# Job                 1000 non-null int64
# Housing             1000 non-null object
# Saving accounts     817 non-null object
# Checking account    606 non-null object
# Credit amount       1000 non-null int64
# Duration            1000 non-null int64
# Purpose             1000 non-null object
# dtypes: int64(4), object(5)
# memory usage: 70.4+ KB

# %%
print("Access particular rows and columns using iloc:")
print(data_frame.iloc[10:20,3:7])
print("\nAccess particular rows and columns using loc:")
print(data_frame.loc[10:20,'Age':'Saving accounts'])
# Out:
# Access particular rows and columns using iloc:
#    Housing Saving accounts Checking account  Credit amount
# 10    rent          little         moderate           1295
# 11    rent          little           little           4308
# 12     own          little         moderate           1567
# 13     own          little           little           1199
# 14    rent          little           little           1403
# 15     own        moderate           little           1282
# 16     own             NaN              NaN           2424
# 17     own             NaN           little           8072
# 18    free          little         moderate          12579
# 19     own      quite rich              NaN           3430
#
# Access particular rows and columns using loc:
#     Age     Sex  Job Housing Saving accounts
# 10   25  female    2    rent          little
# 11   24  female    2    rent          little
# 12   22  female    2     own          little
# ...

# %%
print("How many unique values are there in a particular column:")

for c in data_frame.columns:
    print("Unique values of",c)
    print(data_frame[c].unique())
# Out:
# How many unique values are there in a particular column:
# Unique values of Age
# [67 22 49 45 53 35 61 28 25 24 60 32 44 31 48 26 36 39 42 34 63 27 30 57
#  33 37 58 23 29 52 50 46 51 41 40 66 47 56 54 20 21 38 70 65 74 68 43 55
#  64 75 19 62 59]
# Unique values of Sex
# ['male' 'female']
# Unique values of Job
# [2 1 3 0]
# Unique values of Housing
# ['own' 'free' 'rent']
# Unique values of Saving accounts
# [nan 'little' 'quite rich' 'rich' 'moderate']
# Unique values of Checking account
# ['little' 'moderate' nan 'rich']
# Unique values of Credit amount
# [ 1169  5951  2096  7882  4870  9055  2835  6948  3059  5234  1295  4308
#   1567  1199  1403  1282  2424  8072 12579  3430  2134  2647  2241  1804
#   2069  1374   426   409  2415  6836  1913  4020  5866  1264  1474  4746
#   6110  2100  1225   458  2333  1158  6204  6187  6143  1393  2299  1352
#   7228  2073  5965  1262  3378  2225   783  6468  9566  1961  6229  1391
# ...
