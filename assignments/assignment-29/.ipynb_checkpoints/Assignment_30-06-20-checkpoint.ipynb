# %% [markdown]
# # Assignment 30-06-20

# %% [markdown]
# # CSE-221710304037-N.Kushwanth

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/wbcd.csv")
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0  87139402         B        12.32         12.39           78.85      464.1
# 1   8910251         B        10.60         18.95           69.28      346.4
# 2    905520         B        11.04         16.83           70.92      373.2
# 3    868871         B        11.28         13.39           73.00      384.8
# 4   9012568         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  ...  \
# 0          0.10280           0.06981         0.03987      0.03700  ...
# 1          0.09688           0.11470         0.06387      0.02642  ...
# 2          0.10770           0.07804         0.03046      0.02480  ...
# 3          0.11640           0.11360         0.04635      0.04796  ...
# 4          0.07963           0.06934         0.03393      0.02657  ...
#
#    radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  \
# ...

# %%
df.drop("id",axis=1,inplace=True)
df.head()
# Out:
#   diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0         B        12.32         12.39           78.85      464.1
# 1         B        10.60         18.95           69.28      346.4
# 2         B        11.04         16.83           70.92      373.2
# 3         B        11.28         13.39           73.00      384.8
# 4         B        15.19         13.21           97.65      711.8
#
#    smoothness_mean  compactness_mean  concavity_mean  points_mean  \
# 0          0.10280           0.06981         0.03987      0.03700
# 1          0.09688           0.11470         0.06387      0.02642
# 2          0.10770           0.07804         0.03046      0.02480
# 3          0.11640           0.11360         0.04635      0.04796
# 4          0.07963           0.06934         0.03393      0.02657
#
#    symmetry_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# 0         0.1959  ...         13.50          15.64            86.97
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [diagnosis, radius_mean, texture_mean, perimeter_mean, area_mean, smoothness_mean, compactness_mean, concavity_mean, points_mean, symmetry_mean, dimension_mean, radius_se, texture_se, perimeter_se, area_se, smoothness_se, compactness_se, concavity_se, points_se, symmetry_se, dimension_se, radius_worst, texture_worst, perimeter_worst, area_worst, smoothness_worst, compactness_worst, concavity_worst, points_worst, symmetry_worst, dimension_worst]
# Index: []
#
# [0 rows x 31 columns]

# %%
df.nunique()
# Out:
# diagnosis              2
# radius_mean          456
# texture_mean         479
# perimeter_mean       522
# area_mean            539
# smoothness_mean      474
# compactness_mean     537
# concavity_mean       537
# points_mean          542
# symmetry_mean        432
# dimension_mean       499
# radius_se            540
# texture_se           519
# perimeter_se         533
# area_se              528
# smoothness_se        547
# compactness_se       541
# concavity_se         533
# points_se            507
# symmetry_se          498
# dimension_se         545
# radius_worst         457
# texture_worst        511
# perimeter_worst      514
# area_worst           544
# smoothness_worst     411
# compactness_worst    529
# concavity_worst      539
# points_worst         492
# symmetry_worst       500
# dimension_worst      535
# dtype: int64

# %%
di=pd.get_dummies(df.diagnosis,drop_first=True)
di
# Out:
#      M
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# ..  ..
# 564  0
# 565  0
# 566  1
# 567  0
# 568  1
#
# [569 rows x 1 columns]

# %%
vis=df.drop("diagnosis",axis=1)
for i in vis.columns:
    plt.xlabel("diagnosis")
    plt.ylabel(i)
    plt.scatter(di
                ,vis[i])
    plt.show()

# %%
df.corr()
# Out:
#                    radius_mean  texture_mean  perimeter_mean  area_mean  \
# radius_mean           1.000000      0.323782        0.997855   0.987357
# texture_mean          0.323782      1.000000        0.329533   0.321086
# perimeter_mean        0.997855      0.329533        1.000000   0.986507
# area_mean             0.987357      0.321086        0.986507   1.000000
# smoothness_mean       0.170581     -0.023389        0.207278   0.177028
# compactness_mean      0.506124      0.236702        0.556936   0.498502
# concavity_mean        0.676764      0.302418        0.716136   0.685983
# points_mean           0.822529      0.293464        0.850977   0.823269
# symmetry_mean         0.147741      0.071401        0.183027   0.151293
# dimension_mean       -0.311631     -0.076437       -0.261477  -0.283110
# radius_se             0.679090      0.275869        0.691765   0.732562
# texture_se           -0.097317      0.386358       -0.086761  -0.066280
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),annot=True)

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr()[df.corr()>0.6],annot=True)

# %%
sns.countplot(df.diagnosis)

# %%
x=df.drop("diagnosis",axis=1)
x
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0          12.32         12.39           78.85      464.1          0.10280
# 1          10.60         18.95           69.28      346.4          0.09688
# 2          11.04         16.83           70.92      373.2          0.10770
# 3          11.28         13.39           73.00      384.8          0.11640
# 4          15.19         13.21           97.65      711.8          0.07963
# ..           ...           ...             ...        ...              ...
# 564        13.17         18.22           84.28      537.3          0.07466
# 565        10.26         14.71           66.20      321.6          0.09882
# 566        15.28         22.41           98.92      710.6          0.09057
# 567        14.53         13.98           93.86      644.2          0.10990
# 568        21.37         15.10          141.30     1386.0          0.10010
#
#      compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# ...

# %%
y=df.diagnosis
y
# Out:
# 0      B
# 1      B
# 2      B
# 3      B
# 4      B
#       ..
# 564    B
# 565    B
# 566    M
# 567    B
# 568    M
# Name: diagnosis, Length: 569, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=2)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (398, 30)
# (398,)
# (171, 30)
# (171,)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.metrics import accuracy_score,confusion_matrix,classification_report

# %%
scores=[]
for i in range(1,20):
    knn=KNeighborsClassifier(n_neighbors=i,metric="euclidean")
    knn.fit(x_train,y_train)
    y_pred=knn.predict(x_test)
    scores.append(accuracy_score(y_test,y_pred))
scores
# Out:
# [0.8947368421052632,
#  0.8888888888888888,
#  0.9005847953216374,
#  0.8947368421052632,
#  0.9064327485380117,
#  0.9005847953216374,
#  0.9181286549707602,
#  0.8888888888888888,
#  0.9239766081871345,
#  0.8888888888888888,
#  0.9064327485380117,
#  0.9005847953216374,
#  0.9181286549707602,
#  0.9122807017543859,
#  0.9239766081871345,
#  0.9064327485380117,
#  0.9122807017543859,
#  0.9064327485380117,
#  0.9122807017543859]

# %%
plt.plot(scores,'k--',marker="o",markerfacecolor="red")

# %%
print(scores[8],scores[14])
# Out:
# 0.9239766081871345 0.9239766081871345

# %% [markdown]
# When n_neighbor=9 and 15 Shows a high accuracy

# %%
final_model=KNeighborsClassifier(n_neighbors=9,metric="euclidean")
final_model.fit(x_train,y_train)
final_y_pred=final_model.predict(x_test)
accuracy_score(y_test,final_y_pred)
# Out:
# 0.9239766081871345

# %%
confusion_matrix(y_test,final_y_pred)
# Out:
# array([[97,  3],
#        [10, 61]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,final_y_pred),annot=True,annot_kws={'size':20})

# %%
print(classification_report(y_test,final_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.91      0.97      0.94       100
#            M       0.95      0.86      0.90        71
#
#     accuracy                           0.92       171
#    macro avg       0.93      0.91      0.92       171
# weighted avg       0.93      0.92      0.92       171

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

sc_x_train=pd.DataFrame(sc.fit_transform(x_train),columns=x_train.columns)
sc_x_train.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0     0.065483     -1.355186        0.031346  -0.035592         0.240960
# 1    -0.776400     -0.122579       -0.771922  -0.735368         0.647407
# 2    -0.849363     -1.057826       -0.875635  -0.787151         0.348139
# 3    -0.495772      1.855828       -0.430686  -0.494085         0.543011
# 4    -0.540673     -1.208904       -0.589306  -0.538871        -1.270688
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.482979       -0.357708    -0.046272       1.043490
# 1         -0.311306       -0.538400    -0.554964       0.487938
# 2         -0.852027       -0.784787    -0.557750      -0.867159
# 3          0.675764        0.293648    -0.056654       0.547997
# 4         -1.348603       -0.942352    -1.083888      -0.465510
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
sc_x_test=pd.DataFrame(sc.transform(x_test),columns=x_test.columns)
sc_x_test.head()
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0    -0.767981     -0.055433       -0.795918  -0.721932        -0.589333
# 1    -0.116925     -0.731688       -0.158591  -0.209416        -0.875377
# 2     1.100998     -0.544639        1.047734   0.940735        -0.426476
# 3    -0.922326      1.220340       -0.929322  -0.818221        -0.951934
# 4     0.570612     -1.021855        0.510866   0.408905        -0.045084
#
#    compactness_mean  concavity_mean  points_mean  symmetry_mean  \
# 0         -0.996232       -0.780212    -0.661564       0.810759
# 1         -0.728226       -0.760262    -0.697520       0.281483
# 2          0.438365        0.300001     0.371772      -0.289084
# 3         -0.683493       -0.888348    -1.005166       0.671871
# 4         -0.310914       -0.386171    -0.065263      -0.232778
#
#    dimension_mean  ...  radius_worst  texture_worst  perimeter_worst  \
# ...

# %%
sc_scores=[]
for i in range(1,20):
    knn=KNeighborsClassifier(n_neighbors=i,metric="euclidean")
    knn.fit(sc_x_train,y_train)
    sc_y_pred=knn.predict(sc_x_test)
    sc_scores.append(accuracy_score(y_test,sc_y_pred))
sc_scores
# Out:
# [0.9181286549707602,
#  0.9473684210526315,
#  0.9590643274853801,
#  0.9415204678362573,
#  0.9590643274853801,
#  0.9590643274853801,
#  0.9649122807017544,
#  0.9532163742690059,
#  0.9590643274853801,
#  0.9532163742690059,
#  0.9532163742690059,
#  0.9415204678362573,
#  0.9473684210526315,
#  0.935672514619883,
#  0.9473684210526315,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9415204678362573,
#  0.9473684210526315]

# %%
plt.plot(sc_scores,'k--',marker="o",markerfacecolor="red")

# %%
sc_final_model=KNeighborsClassifier(n_neighbors=7,metric="euclidean")
sc_final_model.fit(sc_x_train,y_train)
sc_final_y_pred=sc_final_model.predict(sc_x_test)
accuracy_score(y_test,sc_final_y_pred)
# Out:
# 0.9649122807017544

# %%
confusion_matrix(y_test,sc_final_y_pred)
# Out:
# array([[99,  1],
#        [ 5, 66]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,sc_final_y_pred),annot=True,annot_kws={'size':20})

# %%
print(classification_report(y_test,sc_final_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            B       0.95      0.99      0.97       100
#            M       0.99      0.93      0.96        71
#
#     accuracy                           0.96       171
#    macro avg       0.97      0.96      0.96       171
# weighted avg       0.97      0.96      0.96       171

# %% [markdown]
# Scalared Data has more accuracy than Original Data
