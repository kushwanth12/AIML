# %% [markdown]
# ### CSE-221710304037-N.Kushwanth

# %% [markdown]
# #### Assignment-22 (22-06-2020)

# %% [markdown]
# Read the dataset from the below path:
# <a href="https://raw.githubusercontent.com/Mounika-Kajjam/Datasets/master/cities.csv">Question</a>
#
# 1.Analyze the  top 5 cities with highest number of female graduates
#
#     a.2.Find the 5 cities with lowest number of female graduates and concatenate the two dataframes of top 5 cities with  bottom 5 cities
#     b.Display only the rows which belong to Kerala, Bihar and Maharashtra.
#     c.Find the  top 10 cities with highest total graduation rate
#     d.Calculate the average child sex ratio of the Kerala State.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("cities.csv")
df.head()
# Out:
#   name_of_city  state_code      state_name  dist_code  population_total  \
# 0      Abohar            3          PUNJAB          9            145238
# 1    Achalpur           27     MAHARASHTRA          7            112293
# 2    Adilabad           28  ANDHRA PRADESH          1            117388
# 3   Adityapur           20       JHARKHAND         24            173988
# 4       Adoni           28  ANDHRA PRADESH         21            166537
#
#    population_male  population_female  0-6_population_total  \
# 0            76840              68398                 15870
# 1            58256              54037                 11810
# 2            59232              58156                 13103
# 3            91495              82493                 23042
# 4            82743              83794                 18406
#
#    0-6_population_male  0-6_population_female  ...  literates_female  \
# 0                 8587                   7283  ...             44972
# ...

# %%
df.columns
# Out:
# Index(['name_of_city', 'state_code', 'state_name', 'dist_code',
#        'population_total', 'population_male', 'population_female',
#        '0-6_population_total', '0-6_population_male', '0-6_population_female',
#        'literates_total', 'literates_male', 'literates_female', 'sex_ratio',
#        'child_sex_ratio', 'effective_literacy_rate_total',
#        'effective_literacy_rate_male', 'effective_literacy_rate_female',
#        'location', 'total_graduates', 'male_graduates', 'female_graduates'],
#       dtype='object')

# %%
df[df.literates_female==df.literates_female.min()]
# Out:
#    name_of_city  state_code state_name  dist_code  population_total  \
# 39      Bagaha           10      BIHAR          1            113012
#
#     population_male  population_female  0-6_population_total  \
# 39            59946              53066                 19070
#
#     0-6_population_male  0-6_population_female  ...  literates_female  \
# 39                 9802                   9268  ...             22247
#
#     sex_ratio  child_sex_ratio  effective_literacy_rate_total  \
# 39        885              946                          60.67
#
#     effective_literacy_rate_male  effective_literacy_rate_female  \
# 39                          69.3                           50.79
#
#                  location  total_graduates male_graduates  female_graduates
# 39  27.1221959,84.0722375             3744           2756               988
#
# [1 rows x 22 columns]

# %%
top5_graduate_female=df.sort_values('literates_female',ascending=False).head()

# %%
top5_graduate_female
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# 141          11007835          5871362            5136473
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 7             5570585          2935869            2634716
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 185               1139146               599007                 540139  ...
# 141               1209275               647938                 561337  ...
# ...

# %%
bottom5_graduate_female=df.sort_values('literates_female',ascending=False).head()
bottom5_graduate_female
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# 141          11007835          5871362            5136473
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 7             5570585          2935869            2634716
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 185               1139146               599007                 540139  ...
# 141               1209275               647938                 561337  ...
# ...

# %%
top_and_bottom=pd.concat([top5_graduate_female,bottom5_graduate_female],axis=0)
top_and_bottom
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 141              Delhi            7    NCT OF DELHI         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 7            Ahmadabad           24         GUJARAT          7
#
#      population_total  population_male  population_female  \
# 185          12478447          6736815            5741632
# 141          11007835          5871362            5136473
# 72            8425970          4401299            4024671
# ...

# %%
k_m_b=pd.concat([df[df.state_name=='KERALA'],df[df.state_name=='MAHARASHTRA'],df[df.state_name=='BIHAR']],axis=0)
k_m_b
# Out:
#     name_of_city  state_code state_name  dist_code  population_total  \
# 14    Alappuzha           32     KERALA         11            174164
# 271       Kochi           32     KERALA          8            601574
# 275      Kollam           32     KERALA         13            349033
# 278   Kozhikode           32     KERALA          4            432097
# 358    Palakkad           32     KERALA          6            131019
# ..           ...         ...        ...        ...               ...
# 371       Patna           10      BIHAR         28           1683200
# 382      Purnia           10      BIHAR          9            280547
# 413     Saharsa           10      BIHAR         12            155175
# 419     Sasaram           10      BIHAR         32            147396
# 440       Siwan           10      BIHAR         16            134458
#
#      population_male  population_female  0-6_population_total  \
# 14             83888              90276                 15434
# ...

# %%
highest_graduate=df.sort_values('total_graduates',ascending=False).head()
highest_graduate
# Out:
#            name_of_city  state_code      state_name  dist_code  \
# 141              Delhi            7    NCT OF DELHI         99
# 185     Greater Mumbai           27     MAHARASHTRA         99
# 72            Bengaluru          29       KARNATAKA         18
# 184  Greater Hyderabad           28  ANDHRA PRADESH         99
# 119            Chennai           33      TAMIL NADU          2
#
#      population_total  population_male  population_female  \
# 141          11007835          5871362            5136473
# 185          12478447          6736815            5741632
# 72            8425970          4401299            4024671
# 184           6809970          3500802            3309168
# 119           4681087          2357633            2323454
#
#      0-6_population_total  0-6_population_male  0-6_population_female  ...  \
# 141               1209275               647938                 561337  ...
# 185               1139146               599007                 540139  ...
# ...

# %%
ker_df=df[df.state_name=='KERALA']
ker_df.child_sex_ratio.mean()
# Out:
# 957.0

# %% [markdown]
# Mean = 70 and Standard Deviation = 10.
# <br>Identify how much area can be found between 70 and 90 with help of Empirical Rule.

# %%
mean=70
std=10
# need to find area under 70 and 90 since 90 is mean+(2*std) so,area under (mean-(2*std),mean+(2*std))i.e.,(50,90) is 95%
#And area from 50 to 70 is equal to 70 to 90 since it is a symmetric curve
area=95/2
area
# Out:
# 47.5
